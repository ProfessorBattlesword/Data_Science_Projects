# %% [markdown]
# # EPA IRIS Chemicals Data Cleaning (from IRIS Assessment)

# %% [markdown]
# ## Import libraries and read in from file dataframe:

# %%
import numpy as np
import pandas as pd

# %%
pd.options.display.max_columns = None

# %%
dirty_chem_df = pd.read_csv('EPA_IRIS_Assessments_2021_dirty.csv')
dirty_chem_df.head()
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION*        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9       19901101 Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9       19901101 Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8       19910101 Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1       19890501 May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0       19911001 Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#                              CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  \
# ...

# %% [markdown]
# ## Rename column for convenience:

# %%
cleaning_df = dirty_chem_df.rename(columns={'LAST SIGNIFICANT REVISION*' : 'LAST SIGNIFICANT REVISION'})
cleaning_df.head()
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9      19901101 Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9      19901101 Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8      19910101 Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1      19890501 May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0      19911001 Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#                              CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  \
# ...

# %%
cleaning_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693 entries, 0 to 692
# Data columns (total 28 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   CHEMICAL NAME                                       693 non-null    object
#  1   CASRN                                               693 non-null    object
#  2   LAST SIGNIFICANT REVISION                           682 non-null    object
#  3   IRIS SUMMARY                                        693 non-null    object
#  4   TOX REVIEW/SUPPORTING DOCUMENT                      693 non-null    object
#  5   LITERATURE SCREENING REVIEW                         693 non-null    object
#  6   CRITICAL EFFECT SYSTEMS                             693 non-null    object
#  7   TUMOR SITE                                          693 non-null    object
# ...

# %% [markdown]
# There are a grand total of 660 rows with 651 non-null values in the "LAST SIGNIFICANT REVISION*" column. The client does not wish for any NaN values to be dropped. Therefore, we need not drop any NaN and clean only those that are non-null.

# %% [markdown]
# # Define dataframe for cleaning process:

# %%
cleaning_df['LAST SIGNIFICANT REVISION'] = cleaning_df['LAST SIGNIFICANT REVISION'].str.split().str.get(1)
cleaning_df.head()
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#                              CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  \
# ...

# %% [markdown]
# ## Data cleaning starts here:

# %%
cleaning_df['CRITICAL EFFECT SYSTEMS'].values[:-1]
# Out:
# array(['Hepatic', 'Hepatic', 'None', 'Nervous',
#        'Nervous                                                            Respiratory',
#        'Hematologic                                                            Hepatic                                                            Nervous                                                            Reproductive                                                            Urinary',
#        'Urinary', 'None', 'None', 'None', 'None',
#        'Developmental                                                            Urinary',
#        'Respiratory', 'Respiratory', 'Nervous', 'Nervous',
#        'Developmental                                                            Nervous                                                            Respiratory',
#        'Developmental                                                            Nervous                                                            Respiratory',
# ...

# %% [markdown]
# Well that's gross...

# %%
cleaning_df['CRITICAL EFFECT SYSTEMS'].str.split().str.join('; ').values[:-1] # preview of possible clean solution
# Out:
# array(['Hepatic', 'Hepatic', 'None', 'Nervous', 'Nervous; Respiratory',
#        'Hematologic; Hepatic; Nervous; Reproductive; Urinary', 'Urinary',
#        'None', 'None', 'None', 'None', 'Developmental; Urinary',
#        'Respiratory', 'Respiratory', 'Nervous', 'Nervous',
#        'Developmental; Nervous; Respiratory',
#        'Developmental; Nervous; Respiratory', 'Respiratory', 'None',
#        'Hematologic', 'None', 'Nervous', 'Nervous', 'Hepatic', 'None',
#        'Hepatic; Urinary', 'Nervous', 'None', 'Hepatic', 'Hepatic',
#        'None', 'Hematologic', 'Respiratory', 'None', 'None', 'None',
#        'Hematologic', 'None', 'None', 'Hematologic', 'Respiratory',
#        'Endocrine; Hepatic', 'None', 'Developmental', 'None',
#        'Dermal; Immune; Ocular', 'Cardiovascular; Dermal',
#        'Hematologic; Immune', 'None', 'Hepatic', 'Hepatic; Reproductive',
#        'None', 'Developmental', 'None', 'Urinary', 'Urinary', 'Urinary',
# ...

# %%
cleaning_df['CRITICAL EFFECT SYSTEMS'] = cleaning_df['CRITICAL EFFECT SYSTEMS'].str.split().str.join('; ') # implementing

# %%
cleaning_df['CRITICAL EFFECT SYSTEMS'].values[:-1] # preview of updated df values
# Out:
# array(['Hepatic', 'Hepatic', 'None', 'Nervous', 'Nervous; Respiratory',
#        'Hematologic; Hepatic; Nervous; Reproductive; Urinary', 'Urinary',
#        'None', 'None', 'None', 'None', 'Developmental; Urinary',
#        'Respiratory', 'Respiratory', 'Nervous', 'Nervous',
#        'Developmental; Nervous; Respiratory',
#        'Developmental; Nervous; Respiratory', 'Respiratory', 'None',
#        'Hematologic', 'None', 'Nervous', 'Nervous', 'Hepatic', 'None',
#        'Hepatic; Urinary', 'Nervous', 'None', 'Hepatic', 'Hepatic',
#        'None', 'Hematologic', 'Respiratory', 'None', 'None', 'None',
#        'Hematologic', 'None', 'None', 'Hematologic', 'Respiratory',
#        'Endocrine; Hepatic', 'None', 'Developmental', 'None',
#        'Dermal; Immune; Ocular', 'Cardiovascular; Dermal',
#        'Hematologic; Immune', 'None', 'Hepatic', 'Hepatic; Reproductive',
#        'None', 'Developmental', 'None', 'Urinary', 'Urinary', 'Urinary',
# ...

# %% [markdown]
# Much better!

# %%
cleaning_df['TUMOR SITE'].values[:-1] # preview
# Out:
# array(['None', 'None', 'None', 'Hepatic', 'Respiratory', 'None', 'None',
#        'None', 'None', 'None', 'None', 'None', 'None', 'None',
#        'Endocrine                                                                Reproductive',
#        'Endocrine                                                                Reproductive',
#        'None', 'None',
#        'Gastrointestinal                                                                Nervous                                                                Respiratory',
#        'None', 'None', 'None', 'None', 'None', 'Hepatic', 'None', 'None',
#        'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None',
#        'None', 'None', 'Immune', 'None', 'None', 'None', 'None', 'None',
#        'Hepatic', 'None', 'None', 'None',
#        'Dermal                                                                Respiratory',
#        'None', 'Respiratory', 'None', 'None', 'None', 'None', 'None',
# ...

# %% [markdown]
# Also gross...

# %%
cleaning_df['TUMOR SITE'] = cleaning_df['TUMOR SITE'].str.split().str.join('; ') # updating

# %%
cleaning_df['TUMOR SITE'].values[:-1] # preview of df values
# Out:
# array(['None', 'None', 'None', 'Hepatic', 'Respiratory', 'None', 'None',
#        'None', 'None', 'None', 'None', 'None', 'None', 'None',
#        'Endocrine; Reproductive', 'Endocrine; Reproductive', 'None',
#        'None', 'Gastrointestinal; Nervous; Respiratory', 'None', 'None',
#        'None', 'None', 'None', 'Hepatic', 'None', 'None', 'None', 'None',
#        'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None',
#        'Immune', 'None', 'None', 'None', 'None', 'None', 'Hepatic',
#        'None', 'None', 'None', 'Dermal; Respiratory', 'None',
#        'Respiratory', 'None', 'None', 'None', 'None', 'None', 'None',
#        'None', 'None', 'None', 'None', 'None', 'None', 'None', 'None',
#        'None', 'None', 'None', 'None', 'Hematologic', 'Hematologic',
#        'Hematologic', 'Hematologic', 'Urinary',
#        'Gastrointestinal; Respiratory', 'Gastrointestinal; Respiratory',
#        'None', 'None', 'None', 'None', 'Respiratory', 'Endocrine',
# ...

# %% [markdown]
# Much better!

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['PESTICIDE'].values[:-1] # preview
# Out:
# array([nan, nan, nan, 'pesticide', nan, 'pesticide', nan, nan, nan, nan,
#        nan, 'pesticide', nan, nan, nan, nan, nan, nan, nan, nan,
#        'pesticide', 'pesticide', 'pesticide', nan, 'pesticide',
#        'pesticide', nan, nan, 'pesticide', 'pesticide', 'pesticide',
#        'pesticide', 'pesticide', nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, 'pesticide', nan, nan, nan, nan, nan, nan, nan, 'pesticide',
#        'pesticide', 'pesticide', 'pesticide', nan, nan, nan, nan, nan,
#        'pesticide', 'pesticide', 'pesticide', 'pesticide', 'pesticide',
#        'pesticide', 'pesticide', nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'pesticide', 'pesticide', nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, 'pesticide', 'pesticide', nan, nan, nan, nan, nan,
# ...

# %% [markdown]
# Looks good. Moving on.

# %%
cleaning_df['ARCHIVE'].values[:-1] # preview
# Out:
# array([nan, nan, nan, 'archive', nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, 'archive', nan, nan, nan, nan, nan, nan, nan,
#        nan, 'archive', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, 'archive', nan, nan, nan, nan, nan, nan, 'archive', nan,
#        'archive', nan, 'archive', nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, 'archive', nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, 'archive', 'archive', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, 'archive', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, 'archive', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %% [markdown]
# Also good. Moving on.

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['NONCANCER ASSESSMENT TYPE'].values[:-1] # preview
# Out:
# array(['Oral', 'Oral', nan, 'Oral', 'Inhalation', 'Oral', 'Oral',
#        'Inhalation', 'Inhalation', 'Oral', nan, 'Oral', 'Oral',
#        'Inahlation', 'Oral', 'Inahlation', 'Oral', 'Inahlation',
#        'Inhalation', nan, 'Oral', 'Oral', 'Oral', 'Oral', 'Oral', 'Oral',
#        'Oral', 'Inhalation', 'Oral', 'Oral', 'Oral', nan, 'Oral',
#        'Inhalation', nan, nan, 'Oral', 'Inhalation', nan, 'Oral', 'Oral',
#        'Inhalation', 'Oral', nan, 'Oral', nan, 'Oral', 'Oral',
#        'Inhalation', nan, 'Oral', 'Oral', 'Oral', 'Oral', nan, 'Oral',
#        'Oral', 'Oral', nan, 'Oral', 'Oral', 'Oral', 'Oral', 'Oral',
#        'Oral', 'Oral', nan, 'Oral', 'Oral', 'Oral', 'Inahlation',
#        'Inahlation', 'Oral', 'Oral', 'Inahlation', nan, nan, nan, 'Oral',
#        nan, nan, 'Oral', 'Oral', 'Oral', 'Inahlation', 'Inahlation',
#        'Inahlation', 'Oral', 'Oral', 'Oral', 'Oral', nan, nan, nan,
#        'Oral', 'Oral', 'Oral', 'Oral', 'Oral', nan, 'Oral', 'Oral',
# ...

# %% [markdown]
# Good.

# %%
cleaning_df['SYSTEM (RfD)'].values[:-1] # preview
# Out:
# array(['Hepatic', 'Hepatic', nan, 'Nervous', nan,
#        'Nervous; Reproductive; Hepatic; Urinary; Hematologic', 'Urinary',
#        nan, nan, 'Other', nan, 'Developmental; Urinary; Other', 'Other',
#        nan, 'Nervous', nan, 'Developmental', nan, nan, nan,
#        'Hematologic; Other', 'Other', 'Nervous', 'Nervous', 'Hepatic',
#        'Other', 'Hepatic; Urinary', nan, 'Other', 'Hepatic; Other',
#        'Hepatic', nan, 'Hematologic', nan, nan, nan, 'Other', nan, nan,
#        'Other', 'Hematologic; Other', nan, 'Endocrine; Hepatic', nan,
#        'Developmental', nan, 'Immune; Dermal; Ocular',
#        'Cardiovascular; Dermal', nan, nan, 'Hepatic',
#        'Reproductive; Hepatic', 'Other', 'Developmental', nan, 'Urinary',
#        'Urinary', 'Urinary', nan, 'Nervous', 'Hematologic; Other',
#        'Urinary; Other', 'Hematologic', 'Developmental', 'Hematologic',
#        'Hematologic', nan, 'Urinary; Gastrointestinal', 'Immune',
# ...

# %% [markdown]
# Good. Moving on.

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['RfD (mg/kg-day)'].values[:-1] # preview
# Out:
# array(['6 x 10 -2', '6 x 10 -2', nan, '4 x 10 -3', nan, '2 x 10 -2',
#        '9 x 10 -1', nan, nan, '1 x 10 -1', nan, '1.3 x 10 -2',
#        '5 x 10 -4', nan, '2 x 10 -3', nan, '5 x 10 -1', nan, nan, nan,
#        '1 x 10 -2', '1.5 x 10 -1', '1 x 10 -3', '1 x 10 -3', '3 x 10 -5',
#        '2.5 x 10 -1', '5 x 10 -3', nan, '4 x 10 -4', '3 x 10 -4',
#        '9 x 10 -3', nan, '2.5 x 10 -3', nan, nan, nan, '2 x 10 -1', nan,
#        nan, '3 x 10 -1', '4 x 10 -4', nan, '1.3 x 10 -2', nan,
#        '7 x 10 -5', nan, '2 x 10 -5', '3 x 10 -4', nan, nan, '9 x 10 -3',
#        '5 x 10 -2', '3.5 x 10 -2', '4 x 10 -4', nan, '2 x 10 -1',
#        '2 x 10 -1', '2 x 10 -1', nan, '4 x 10 -3', '3 x 10 -2',
#        '2.5 x 10 -2', '3 x 10 -1', '5 x 10 -2', '3 x 10 -2', '3 x 10 -2',
#        nan, '1 x 10 -1', '4 x 10 -3', '4 x 10 -3', nan, nan, '3 x 10 -3',
#        '3 x 10 -4', nan, nan, nan, nan, '4', nan, nan, '2 x 10 -3',
#        '2 x 10 -3', '2 x 10 -3', nan, nan, nan, '1 x 10 -4',
# ...

# %% [markdown]
# Good. Moving on.

# %%
cleaning_df['BASIS (RfD)'].values[:-1] # preview
# Out:
# array(['Hepatotoxicity', 'Hepatotoxicity', nan, 'Inhibition of brain ChE',
#        nan,
#        'Salivation; increased ALT and ornithine carbamyl transferase; significant increases in triglyceride and decreased blood glucose levels; histopathological changes in kidneys and testes of males',
#        'Nephropathy', nan, nan, 'General Toxicity', nan,
#        'Mortality and kidney lesions', 'Decreased survival', nan,
#        'Degenerative nerve changes', nan, 'Reduced pup weight', nan, nan,
#        nan, 'Hemosiderosis; hemolytic anemia', 'No adverse effects',
#        'Sweating as clinical sign of AChe inhibition',
#        'Brain ChE inhibition in females', 'Liver toxicity',
#        'Decreased body weight',
#        'Impaired renal function and increased liver and kidney weights',
#        nan, 'Body weight and clinical parameters',
#        'Increased organ weights', 'Liver toxicity', nan,
#        'Increased mean blood sugar concentration; slight hypothermia',
# ...

# %% [markdown]
# Looks good. Moving on.

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['PoD (RfD)'].values[:-1] # preview
# Out:
# array(['NOAEL   :   1.75    x 102 mg/kg-day',
#        'NOAEL   :   1.75    x 102 mg/kg-day', nan,
#        'LEL   :    1.2    x 10-1 mg/kg-day', nan,
#        'NOAEL   :   2    mg/kg-day', 'NOAEL   :   900    mg/kg-day', nan,
#        nan, 'NOAEL   :   4.23    x 102 mg/kg-day', nan,
#        'NOEL   :   1.25    mg/kg-day', 'NOAEL   :   0.05    mg/kg-day',
#        nan, 'HED      (BMDL):   0.053    mg/kg-day', nan,
#        'NOAEL   :   5.3    x 101 mg/kg-day', nan, nan, nan,
#        'NOAEL   :   1    mg/kg-day', 'NOEL   :   1.5    x 101 mg/kg-day',
#        'NOAEL   :   1    x 10-2 mg/kg-day',
#        'NOAEL   :   1.1    x 10-1 mg/kg-day',
#        'LOAEL   :   2.5    x 10-2 mg/kg-day',
#        'NOEL   :   2.5    x 101 mg/kg-day', 'NOEL   :   4.8    mg/kg-day',
#        nan, 'NOAEL   :   4.3    x 10-2 mg/kg-day',
#        'NOEL   :   3.3    x 10-1 mg/kg-day',
#        'NOEL   :   8.6    mg/kg-day', nan,
#        'NOEL   :   2.5    x 10-1 mg/kg-day', nan, nan, nan,
# ...

# %% [markdown]
# Needs some tidying.

# %%
cleaning_df['PoD (RfD)'].str.split().str.join(' ').str.replace(' :', ':') # preview possible solution
# Out:
# 0      NOAEL: 1.75 x 102 mg/kg-day
# 1      NOAEL: 1.75 x 102 mg/kg-day
# 2                              NaN
# 3        LEL: 1.2 x 10-1 mg/kg-day
# 4                              NaN
#                   ...
# 688          LOAEL: 0.91 mg/kg-day
# 689          LOAEL: 0.91 mg/kg-day
# 690    NOAEL: 2.43 x 101 mg/kg-day
# 691          LOAEL: 3.48 mg/kg-day
# 692     LOAEL: 2.5 x 101 mg/kg-day
# Name: PoD (RfD), Length: 693, dtype: object

# %%
cleaning_df['PoD (RfD)'] = cleaning_df['PoD (RfD)'].str.split().str.join(' ').str.replace(' :', ':') # updating

# %%
cleaning_df['PoD (RfD)'].values[:-1] # preview updated df values
# Out:
# array(['NOAEL: 1.75 x 102 mg/kg-day', 'NOAEL: 1.75 x 102 mg/kg-day', nan,
#        'LEL: 1.2 x 10-1 mg/kg-day', nan, 'NOAEL: 2 mg/kg-day',
#        'NOAEL: 900 mg/kg-day', nan, nan, 'NOAEL: 4.23 x 102 mg/kg-day',
#        nan, 'NOEL: 1.25 mg/kg-day', 'NOAEL: 0.05 mg/kg-day', nan,
#        'HED (BMDL): 0.053 mg/kg-day', nan, 'NOAEL: 5.3 x 101 mg/kg-day',
#        nan, nan, nan, 'NOAEL: 1 mg/kg-day', 'NOEL: 1.5 x 101 mg/kg-day',
#        'NOAEL: 1 x 10-2 mg/kg-day', 'NOAEL: 1.1 x 10-1 mg/kg-day',
#        'LOAEL: 2.5 x 10-2 mg/kg-day', 'NOEL: 2.5 x 101 mg/kg-day',
#        'NOEL: 4.8 mg/kg-day', nan, 'NOAEL: 4.3 x 10-2 mg/kg-day',
#        'NOEL: 3.3 x 10-1 mg/kg-day', 'NOEL: 8.6 mg/kg-day', nan,
#        'NOEL: 2.5 x 10-1 mg/kg-day', nan, nan, nan,
#        'NOEL: 2.143 x 102 mg/kg-day', nan, nan,
#        'NOEL: 1.000 x 103 mg/kg-day', 'LOAEL: 3.5 x 10-1 mg/kg-day', nan,
#        'NOEL: 1.25 mg/kg-day', nan, 'NOAEL: 7 x 10-3 mg/kg-day', nan,
# ...

# %% [markdown]
# Much better.

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['COMPOSITE UF (RfD)'].values[:-1] # preview
# Out:
# array(['3000', '3000', nan, '30', nan, '100', '1000', nan, nan, '3000',
#        nan, '100', '100', nan, '30', nan, '100', nan, nan, nan, '100',
#        '100', '10', '100', '1000', '100', '1000', nan, '100', '1000',
#        '1000', nan, '100', nan, nan, nan, '1000', nan, nan, '3000',
#        '1000', nan, '100', nan, '100', nan, '300', '3', nan, nan, '100',
#        '1000', '100', '300', nan, '300', '300', '300', nan, '100', '100',
#        '100', '100', '100', '100', '100', nan, '1000', '300', '300', nan,
#        nan, '1000', '300', nan, nan, nan, nan, '1', nan, nan, '300',
#        '300', '300', nan, nan, nan, '1000', '100', '30      MF: 10',
#        '1000', nan, nan, nan, '1000', '66', '300', '300', '300', nan,
#        '3000', '1000', nan, nan, nan, '1000', nan, '1000', '1000', nan,
#        nan, '300', '300', nan, '1000', '100', nan, '1000', '100', nan,
#        '1000', nan, '10', '10', nan, '100', '1000', '100', '100', '100',
# ...

# %% [markdown]
# A few could be a bit more tidy.

# %%
cleaning_df['COMPOSITE UF (RfD)'] = cleaning_df['COMPOSITE UF (RfD)'].str.split().str.join(' ') # updating

# %%
cleaning_df['COMPOSITE UF (RfD)'].values[:-1] # preview updated df values
# Out:
# array(['3000', '3000', nan, '30', nan, '100', '1000', nan, nan, '3000',
#        nan, '100', '100', nan, '30', nan, '100', nan, nan, nan, '100',
#        '100', '10', '100', '1000', '100', '1000', nan, '100', '1000',
#        '1000', nan, '100', nan, nan, nan, '1000', nan, nan, '3000',
#        '1000', nan, '100', nan, '100', nan, '300', '3', nan, nan, '100',
#        '1000', '100', '300', nan, '300', '300', '300', nan, '100', '100',
#        '100', '100', '100', '100', '100', nan, '1000', '300', '300', nan,
#        nan, '1000', '300', nan, nan, nan, nan, '1', nan, nan, '300',
#        '300', '300', nan, nan, nan, '1000', '100', '30 MF: 10', '1000',
#        nan, nan, nan, '1000', '66', '300', '300', '300', nan, '3000',
#        '1000', nan, nan, nan, '1000', nan, '1000', '1000', nan, nan,
#        '300', '300', nan, '1000', '100', nan, '1000', '100', nan, '1000',
#        nan, '10', '10', nan, '100', '1000', '100', '100', '100', '100',
# ...

# %% [markdown]
# Better. Moving on.

# %%
cleaning_df['CONFIDENCE (RfD)'].values[:-1] # preview
# Out:
# array(['Low', 'Low', nan, 'High', nan, 'High', 'Medium', nan, nan, 'Low',
#        nan, 'Medium', 'Medium/High', nan, 'Medium/High', nan, 'High', nan,
#        nan, nan, 'High', 'Low', 'Medium', 'Medium', 'Medium', 'High',
#        'Low', nan, 'Medium', 'High', 'Low', nan, 'Medium', nan, nan, nan,
#        'Low', nan, nan, 'Low', 'Low', nan, 'High', nan, 'Medium', nan,
#        'Medium', 'Medium', nan, nan, 'High', 'Medium', 'High', 'High',
#        nan, 'Medium', 'Medium', 'Medium', nan, 'Medium', 'High', 'High',
#        'Medium', 'High', 'Medium', 'Medium', nan, 'Low', 'Medium',
#        'Medium', nan, nan, 'Medium', 'Medium', nan, nan, nan, nan,
#        'Medium', nan, nan, 'Low/Medium', 'Low/Medium', 'Low/Medium', nan,
#        nan, nan, 'Low', 'High', 'Medium/High', 'Low', nan, nan, nan,
#        'High', 'High', 'Medium', 'Medium', 'Medium', nan, 'Low/Medium',
#        'Medium', nan, nan, nan, 'Medium', nan, 'Medium', 'Medium', nan,
# ...

# %% [markdown]
# Looks good. Moving on.

# %%
cleaning_df['SYSTEM (RfC)'].values[:-1] # preview
# Out:
# array([nan, nan, nan, nan, 'Nervous; Respiratory', nan, nan, 'Other',
#        'Other', nan, nan, nan, nan, 'Respiratory', nan, 'Nervous', nan,
#        'Nervous; Respiratory', 'Respiratory', nan, nan, nan, nan, nan,
#        nan, nan, nan, 'Nervous', nan, nan, nan, nan, nan, 'Respiratory',
#        nan, nan, nan, 'Hematologic', nan, nan, nan, 'Respiratory', nan,
#        nan, nan, nan, nan, nan, 'Immune; Hematologic', nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, 'Immune', 'Immune', nan, nan, 'Developmental',
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Immune; Respiratory',
#        'Immune; Respiratory', 'Immune; Respiratory', nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Hepatic',
#        'Hepatic', nan, nan, nan, nan, nan, 'Nervous; Respiratory', nan,
#        nan, nan, 'Reproductive', nan, nan, 'Urinary', nan, nan, nan, nan,
# ...

# %% [markdown]
# Looks good. Moving on.

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['RfC (mg/m^3)'].values[:-1] # preview
# Out:
# array([nan, nan, nan, nan, '9 x 10 -3', nan, nan, '6 x 10 -2',
#        '6 x 10 -2', nan, nan, nan, nan, '2 x 10 -5', nan, '6 x 10 -3',
#        nan, '1 x 10 -3', '2 x 10 -3', nan, nan, nan, nan, nan, nan, nan,
#        nan, '1 x 10 -3', nan, nan, nan, nan, nan, '5 x 10 -1', nan, nan,
#        nan, '1 x 10 -3', nan, nan, nan, '2 x 10 -4', nan, nan, nan, nan,
#        nan, nan, '5 x 10 -5', nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        '3 x 10 -2', '3 x 10 -2', nan, nan, '2 x 10 -6', nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, '2 x 10 -5', '2 x 10 -5',
#        '2 x 10 -5', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, '6 x 10 -2 (Chronic)',
#        '2 x 10 -1 (Subchronic)', nan, nan, nan, nan, nan, '5 x 10 -3',
#        nan, nan, nan, '2 x 10 -3', nan, nan, '5', nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, '7 x 10 -1', nan,
# ...

# %% [markdown]
# Looks good. Moving on.

# %%
cleaning_df = cleaning_df.rename(columns={'Basis (RfC)' : 'BASIS (RfC)'}) # updating column name (missed this in column creation)

# %%
cleaning_df['BASIS (RfC)'].values[:-1] # preview updated df values
# Out:
# array([nan, nan, nan, nan, 'Degeneration of olfactory epithelium', nan,
#        nan, 'Mortality', 'Mortality', nan, nan, nan, nan, 'Nasal lesions',
#        nan, 'Degenerative nerve changes', nan,
#        'Degeneration of the nasal olfactory epithelium',
#        'Degeneration and inflammation of nasal respiratory epithelium; hyperplasia of mucous secreting cells',
#        nan, nan, nan, nan, nan, nan, nan, nan,
#        'Functional and histological peripheral neurotoxicity', nan, nan,
#        nan, nan, nan, 'Decreased lung function and respiratory symptoms',
#        nan, nan, nan, 'Methemoglobin increase; spleen toxicity', nan, nan,
#        nan, 'Pulmonary toxicity; chronic interstitial inflammation', nan,
#        nan, nan, nan, nan, nan,
#        'Increased hemolysis; abnormal RBC morphology; and increased spleen weight',
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %% [markdown]
# Looks good. Moving on.

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['PoD (RfC)'].values[:-1] # preview
# Out:
# array([nan, nan, nan, nan, 'NOAEL      (HEC):   8.7    mg/m3', nan, nan,
#        'NOAEL      (HEC):   6.0    x 101 mg/m3',
#        'NOAEL      (HEC):   6.0    x 101 mg/m3', nan, nan, nan, nan,
#        'LOAEL      (HEC):   0.02    mg/m3', nan,
#        'HEC  5    (BMDL):   0.18    mg/m3', nan,
#        'LOAEL      (HEC):   3.3    x 10-1 mg/m3',
#        'LOAEL      (HEC):   1.9    mg/m3', nan, nan, nan, nan, nan, nan,
#        nan, nan, 'NOAEL      (HEC):   3.6    mg/m3', nan, nan, nan, nan,
#        nan, 'NOAEL      (ADJ):   4.9    mg/m3', nan, nan, nan,
#        'NOAEL      (HEC):   3.4    mg/m3', nan, nan, nan,
#        'BMC  10    (HEC):   7.4    x 10-2 mg/m3', nan, nan, nan, nan, nan,
#        nan, 'NOAEL      (HEC):   1.4    x 10-2 mg/m3', nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, 'BMCL   :   8.2    mg/m3',
#        'BMCL   :   8.2    mg/m3', nan, nan, 'LOAEL :  4.6   x 10-3 mg/m3',
# ...

# %% [markdown]
# Needs a bit of clean up.

# %%
cleaning_df['PoD (RfC)'] = cleaning_df['PoD (RfC)'].str.split().str.join(' ') # updating

# %%
cleaning_df['PoD (RfC)'].values[:-1] # preview updated df values
# Out:
# array([nan, nan, nan, nan, 'NOAEL (HEC): 8.7 mg/m3', nan, nan,
#        'NOAEL (HEC): 6.0 x 101 mg/m3', 'NOAEL (HEC): 6.0 x 101 mg/m3',
#        nan, nan, nan, nan, 'LOAEL (HEC): 0.02 mg/m3', nan,
#        'HEC 5 (BMDL): 0.18 mg/m3', nan, 'LOAEL (HEC): 3.3 x 10-1 mg/m3',
#        'LOAEL (HEC): 1.9 mg/m3', nan, nan, nan, nan, nan, nan, nan, nan,
#        'NOAEL (HEC): 3.6 mg/m3', nan, nan, nan, nan, nan,
#        'NOAEL (ADJ): 4.9 mg/m3', nan, nan, nan, 'NOAEL (HEC): 3.4 mg/m3',
#        nan, nan, nan, 'BMC 10 (HEC): 7.4 x 10-2 mg/m3', nan, nan, nan,
#        nan, nan, nan, 'NOAEL (HEC): 1.4 x 10-2 mg/m3', nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, 'BMCL : 8.2 mg/m3', 'BMCL : 8.2 mg/m3', nan,
#        nan, 'LOAEL : 4.6 x 10-3 mg/m3', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, 'LOAEL (HEC): 2.0 x 10-4 mg/m3',
#        'LOAEL (HEC): 2.0 x 10-4 mg/m3', 'LOAEL (HEC): 2.0 x 10-4 mg/m3',
# ...

# %% [markdown]
# Better. Moving on.

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['COMPOSITE UF (RfC)'].values[:-1] # preview
# Out:
# array([nan, nan, nan, nan, '1000', nan, nan, '100      MF: 10',
#        '100      MF: 10', nan, nan, nan, nan, '1000', nan, '30', nan,
#        '300', '1000', nan, nan, nan, nan, nan, nan, nan, nan, '3000', nan,
#        nan, nan, nan, nan, '10', nan, nan, nan, '3000', nan, nan, nan,
#        '300', nan, nan, nan, nan, nan, nan, '300', nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, '300', '300', nan, nan, '3000', nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, '10', '10', '10', nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '1000',
#        '300', nan, nan, nan, nan, nan, '100', nan, nan, nan, '1000', nan,
#        nan, '100', nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, '30', nan, '100', nan, nan, nan, '1000', nan, nan,
#        nan, nan, nan, '1000', '1000', nan, nan, nan, nan, nan, nan,
# ...

# %% [markdown]
# A few look a bit wonky.

# %%
cleaning_df['COMPOSITE UF (RfC)'] = cleaning_df['COMPOSITE UF (RfC)'].str.split().str.join(' ') # updating

# %%
cleaning_df['COMPOSITE UF (RfC)'].values[:-1] # preview updated df values
# Out:
# array([nan, nan, nan, nan, '1000', nan, nan, '100 MF: 10', '100 MF: 10',
#        nan, nan, nan, nan, '1000', nan, '30', nan, '300', '1000', nan,
#        nan, nan, nan, nan, nan, nan, nan, '3000', nan, nan, nan, nan, nan,
#        '10', nan, nan, nan, '3000', nan, nan, nan, '300', nan, nan, nan,
#        nan, nan, nan, '300', nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '300',
#        '300', nan, nan, '3000', nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, '10', '10', '10', nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, '1000', '300', nan, nan, nan, nan,
#        nan, '100', nan, nan, nan, '1000', nan, nan, '100', nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, '30', nan,
#        '100', nan, nan, nan, '1000', nan, nan, nan, nan, nan, '1000',
#        '1000', nan, nan, nan, nan, nan, nan, '3000', '3000', nan, nan,
# ...

# %% [markdown]
# Better. Moving on.

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['CONFIDENCE (RfC)'].values[:-1] # preview
# Out:
# array([nan, nan, nan, nan, 'Low', nan, nan, 'Medium', 'Medium', nan, nan,
#        nan, nan, 'Medium', nan, 'Medium', nan, 'Medium', 'Medium', nan,
#        nan, nan, nan, nan, nan, nan, nan, 'Low', nan, nan, nan, nan, nan,
#        'Medium', nan, nan, nan, 'Low', nan, nan, nan, 'Medium', nan, nan,
#        nan, nan, nan, nan, 'Medium', nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, 'Medium', 'Medium', nan, nan, 'Low/Medium', nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, 'Medium', 'Medium', 'Medium', nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, 'Low/Medium', 'Medium', nan, nan, nan, nan, nan, 'High', nan,
#        nan, nan, 'Medium', nan, nan, 'Medium', nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, 'Medium', nan,
#        'Medium', nan, nan, nan, 'Low', nan, nan, nan, nan, nan, 'Low',
# ...

# %% [markdown]
# Looks good. Moving on.

# %%
cleaning_df['WOE CHARACTERIZATION'].values[:-1] # preview
# Out:
# array([nan, nan, 'D (Not classifiable as to human carcinogenicity)',
#        'C (Possible human carcinogen)',
#        'B2 (Probable human carcinogen - based on sufficient evidence of carcinogenicity in animals)',
#        nan,
#        'Data are inadequate for an assessment of human carcinogenic potential',
#        'D (Not classifiable as to human carcinogenicity)',
#        'Carcinogenic potential cannot be determined',
#        'D (Not classifiable as to human carcinogenicity)',
#        'D (Not classifiable as to human carcinogenicity)', nan,
#        'Data are inadequate for an assessment of human carcinogenic potential',
#        'Data are inadequate for an assessment of human carcinogenic potential',
#        'Likely to be carcinogenic to humans',
#        'Likely to be carcinogenic to humans', nan, nan,
#        'B1 (Probable human carcinogen - based on limited evidence of carcinogenicity in humans)',
#        'D (Not classifiable as to human carcinogenicity)', nan, nan,
# ...

# %% [markdown]
# A bit dirty.

# %%
cleaning_df['WOE CHARACTERIZATION'].str.replace('\n', '').str.split().str.join(' ').values[:-1] # preview of possible solution
# Out:
# array([nan, nan, 'D (Not classifiable as to human carcinogenicity)',
#        'C (Possible human carcinogen)',
#        'B2 (Probable human carcinogen - based on sufficient evidence of carcinogenicity in animals)',
#        nan,
#        'Data are inadequate for an assessment of human carcinogenic potential',
#        'D (Not classifiable as to human carcinogenicity)',
#        'Carcinogenic potential cannot be determined',
#        'D (Not classifiable as to human carcinogenicity)',
#        'D (Not classifiable as to human carcinogenicity)', nan,
#        'Data are inadequate for an assessment of human carcinogenic potential',
#        'Data are inadequate for an assessment of human carcinogenic potential',
#        'Likely to be carcinogenic to humans',
#        'Likely to be carcinogenic to humans', nan, nan,
#        'B1 (Probable human carcinogen - based on limited evidence of carcinogenicity in humans)',
#        'D (Not classifiable as to human carcinogenicity)', nan, nan,
# ...

# %% [markdown]
# Preview looks good. Applying script.

# %%
cleaning_df['WOE CHARACTERIZATION'] = cleaning_df['WOE CHARACTERIZATION'].str.replace('\n', '').str.split().str.join(' ') # updating

# %%
cleaning_df['WOE CHARACTERIZATION'].values[:-1] # preview of updated df values
# Out:
# array([nan, nan, 'D (Not classifiable as to human carcinogenicity)',
#        'C (Possible human carcinogen)',
#        'B2 (Probable human carcinogen - based on sufficient evidence of carcinogenicity in animals)',
#        nan,
#        'Data are inadequate for an assessment of human carcinogenic potential',
#        'D (Not classifiable as to human carcinogenicity)',
#        'Carcinogenic potential cannot be determined',
#        'D (Not classifiable as to human carcinogenicity)',
#        'D (Not classifiable as to human carcinogenicity)', nan,
#        'Data are inadequate for an assessment of human carcinogenic potential',
#        'Data are inadequate for an assessment of human carcinogenic potential',
#        'Likely to be carcinogenic to humans',
#        'Likely to be carcinogenic to humans', nan, nan,
#        'B1 (Probable human carcinogen - based on limited evidence of carcinogenicity in humans)',
#        'D (Not classifiable as to human carcinogenicity)', nan, nan,
# ...

# %% [markdown]
# Much nicer.

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['FRAMEWORK FOR WOE CHARACTERIZATION'].values[:-1] # preview
# Out:
# array([nan, nan,
#        'Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1986)',
#        'Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1986)',
#        'Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1986)', nan,
#        'Revised Draft Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1999)',
#        'Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1986)',
#        'Proposed Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1996)',
#        'Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1986)',
#        'Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1986)', nan,
#        'Revised Draft Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1999)',
#        'Revised Draft Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1999)',
#        'Guidelines for Carcinogen Risk Assessment (U.S. EPA, 2005)',
#        'Guidelines for Carcinogen Risk Assessment (U.S. EPA, 2005)', nan,
# ...

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['WOE BASIS'].values[:-1] # preview
# Out:
# array([nan, nan,
#        'Based on no human data and inadequate data from animal bioassays.\nThis may be a synopsis of the full weight-of-evidence narrative.\n',
#        'The classification is based on increased incidence of hepatocellular carcinomas and adenomas in female mice.\nThis may be a synopsis of the full weight-of-evidence narrative.\n',
#        'Based on increased incidence of nasal tumors in male and female rats and laryngeal tumors in male and female hamsters after inhalation exposure.\nThis may be a synopsis of the full weight-of-evidence narrative.\n',
#        nan,
#        'In accordance with the Draft Revised Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1999) data are inadequate for an assessment of the human carcinogenic potential of acetone.\nThis may be a synopsis of the full weight-of-evidence narrative.\n',
# ...

# %%
cleaning_df['WOE BASIS'].str.replace('\n', ' ').str.split().str.join(' ').values[:-1] # preview of possible solution
# Out:
# array([nan, nan,
#        'Based on no human data and inadequate data from animal bioassays. This may be a synopsis of the full weight-of-evidence narrative.',
#        'The classification is based on increased incidence of hepatocellular carcinomas and adenomas in female mice. This may be a synopsis of the full weight-of-evidence narrative.',
#        'Based on increased incidence of nasal tumors in male and female rats and laryngeal tumors in male and female hamsters after inhalation exposure. This may be a synopsis of the full weight-of-evidence narrative.',
#        nan,
#        'In accordance with the Draft Revised Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1999) data are inadequate for an assessment of the human carcinogenic potential of acetone. This may be a synopsis of the full weight-of-evidence narrative.',
# ...

# %% [markdown]
# Preview looks good. Applying script.

# %%
cleaning_df['WOE BASIS'] = cleaning_df['WOE BASIS'].str.replace('\n', ' ').str.split().str.join(' ') # updating

# %%
cleaning_df['WOE BASIS'].values[:-1] # preview of updated df values
# Out:
# array([nan, nan,
#        'Based on no human data and inadequate data from animal bioassays. This may be a synopsis of the full weight-of-evidence narrative.',
#        'The classification is based on increased incidence of hepatocellular carcinomas and adenomas in female mice. This may be a synopsis of the full weight-of-evidence narrative.',
#        'Based on increased incidence of nasal tumors in male and female rats and laryngeal tumors in male and female hamsters after inhalation exposure. This may be a synopsis of the full weight-of-evidence narrative.',
#        nan,
#        'In accordance with the Draft Revised Guidelines for Carcinogen Risk Assessment (U.S. EPA, 1999) data are inadequate for an assessment of the human carcinogenic potential of acetone. This may be a synopsis of the full weight-of-evidence narrative.',
# ...

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['QUANT. EST. OF CARC. RISK FROM ORAL EXPOSURE'].values[:-1] # preview
# Out:
# array([nan, nan, nan,
#        'Oral Slope Factor:\n                8.7\n                 x 10-3\n                per mg/kg-day\n                \n                \n                  \nDrinking Water Unit Risk:\n                  2.5\n                   x 10-7\n                  per µg/L\n                  \n                \n                \n                  Extrapolation Method:\n                  Linearized multistage procedure, extra risk \nTumor site(s): Hepatic \nTumor type(s): Liver adenomas and carcinomas\n                 (Chevron Chemical, 1982a)',
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %% [markdown]
# Very messy.

# %%
cleaning_df['QUANT. EST. OF CARC. RISK FROM ORAL EXPOSURE'].str.split().str.join(' ').str.replace(' Drinking', '\nDrinking').str.replace(' Extrapolation', '\nExtrapolation').str.replace(' Tumor', '\nTumor').str.replace(' Note', '\nNote').values[:-1] # preview
# Out:
# array([nan, nan, nan,
#        'Oral Slope Factor: 8.7 x 10-3 per mg/kg-day\nDrinking Water Unit Risk: 2.5 x 10-7 per µg/L\nExtrapolation Method: Linearized multistage procedure, extra risk\nTumor site(s): Hepatic\nTumor type(s): Liver adenomas and carcinomas (Chevron Chemical, 1982a)',
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'Oral Slope Factor: 5 x 10-1 per mg/kg-day\nExtrapolation Method: Multistage model with linear extrapolation from the point of departure (BMDL), summed risk.\nTumor site(s): Reproductive, Endocrine\nTumor type(s): thyroid tumors and tunica vaginalis mesotheliomas (Johnson et al., 1986)\nNote: ADAF -- EPA has concluded that acrylamide is carcinogenic by a mutagenic mode of action. Application of age-dependent adjustment factors (ADAFs) to the oral slope factor is recommended in combination with appropriate exposure data when assessing risk associated with early-life exposure.',
# ...

# %%
cleaning_df['QUANT. EST. OF CARC. RISK FROM ORAL EXPOSURE'] = cleaning_df['QUANT. EST. OF CARC. RISK FROM ORAL EXPOSURE'].str.split().str.join(' ').str.replace(' Drinking', '\nDrinking').str.replace(' Extrapolation', '\nExtrapolation').str.replace(' Tumor', '\nTumor').str.replace(' Note', '\nNote') # updating

# %%
# this is how a cell in this column will appear in MS Excel
# Note: I'm certain pandas can extract info to form new columns for each of these categories, but I need to expand my knowledge on this

print(cleaning_df['QUANT. EST. OF CARC. RISK FROM ORAL EXPOSURE'].loc[3])
# Out:
# Oral Slope Factor: 8.7 x 10-3 per mg/kg-day
# Drinking Water Unit Risk: 2.5 x 10-7 per µg/L
# Extrapolation Method: Linearized multistage procedure, extra risk
# Tumor site(s): Hepatic
# Tumor type(s): Liver adenomas and carcinomas (Chevron Chemical, 1982a)

# %%
cleaning_df.head() # for ease of reference
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
cleaning_df['QUANT. EST. OF CARC. RISK FROM INHALATION EXPOSURE'].str.split().str.join(' ').str.replace(' Extrapolation', '\nExtrapolation').str.replace(' Tumor', '\nTumor').str.replace(' Note', '\nNote').values[:-1] # preview
# Out:
# array([nan, nan, nan, nan,
#        'Inhalation Unit Risk: 2.2 x 10-6 per µg/m3\nExtrapolation Method: Linearized multistage-variable exposure input form (extra risk)\nTumor site(s): Respiratory\nTumor type(s): Nasal squamous cell carcinoma or adenocarcinoma (Woutersen and Appleman, 1984)',
#        nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        'Inhalation Unit Risk: 1 x 10-4 per µg/m3\nExtrapolation Method: Multistage model with linear extrapolation from the point of departure (BMDL), summed risk.\nTumor site(s): Endocrine, Reproductive\nTumor type(s): thyroid tumors and tunica vaginalis mesotheliomas (Johnson et al., 1986)\nNote: ADAF -- EPA has concluded that acrylamide is carcinogenic by a mutagenic mode of action. Application of age-dependent adjustment factors (ADAFs) to the inhalation unit risk is recommended in combination with appropriate exposure data when assessing risk associated with early-life exposure.',
# ...

# %%
cleaning_df['QUANT. EST. OF CARC. RISK FROM INHALATION EXPOSURE'] = cleaning_df['QUANT. EST. OF CARC. RISK FROM INHALATION EXPOSURE'].str.split().str.join(' ').str.replace(' Extrapolation', '\nExtrapolation').str.replace(' Tumor', '\nTumor').str.replace(' Note', '\nNote') # updating

# %%
# this is how a cell in this column will appear in MS Excel
# Note: I'm certain pandas can extract info to form new columns, but I need to expand my knowledge on this

print(cleaning_df['QUANT. EST. OF CARC. RISK FROM INHALATION EXPOSURE'].loc[4])
# Out:
# Inhalation Unit Risk: 2.2 x 10-6 per µg/m3
# Extrapolation Method: Linearized multistage-variable exposure input form (extra risk)
# Tumor site(s): Respiratory
# Tumor type(s): Nasal squamous cell carcinoma or adenocarcinoma (Woutersen and Appleman, 1984)

# %%
clean_chem_df = cleaning_df # dataframe columns cleaned
clean_chem_df.head()
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 1    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 1                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
#
#   CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  ARCHIVE  \
# 0                 Hepatic         None        NaN      NaN
# ...

# %%
clean_chem_df = clean_chem_df.drop_duplicates() # remove duplicated rows

# %%
clean_chem_df.head() # preview cleaned dataframe
# Out:
#     CHEMICAL NAME       CASRN LAST SIGNIFICANT REVISION        IRIS SUMMARY  \
# 0    Acenaphthene     83-32-9               Nov-01-1990    (PDF 7 pp, 89 K)
# 2  Acenaphthylene    208-96-8               Jan-01-1991    (PDF 6 pp, 82 K)
# 3        Acephate  30560-19-1               May-01-1989  (PDF 13 pp, 114 K)
# 4    Acetaldehyde     75-07-0               Oct-01-1991  (PDF 20 pp, 147 K)
# 5      Acetochlor  34256-82-1               Sep-01-1993  (PDF 14 pp, 126 K)
#
#   TOX REVIEW/SUPPORTING DOCUMENT LITERATURE SCREENING REVIEW  \
# 0                  Not Available                          No
# 2                  Not Available                          No
# 3                  Not Available                         Yes
# 4                  Not Available                          No
# 5                  Not Available                         Yes
#
#                              CRITICAL EFFECT SYSTEMS   TUMOR SITE  PESTICIDE  \
# ...

# %%
len(clean_chem_df) # check length
# Out:
# 692

# %%
clean_chem_df[clean_chem_df['CHEMICAL NAME'].duplicated()].tail() # preview last few rows of df for which there are duplicate chemical names (multiple tables etc for certain chemical asessment pages)
# Out:
#           CHEMICAL NAME      CASRN LAST SIGNIFICANT REVISION  \
# 681      Vinyl chloride    75-01-4               Aug-07-2000
# 685             Xylenes  1330-20-7               Feb-21-2003
# 687  Zinc and Compounds  7440-66-6               Aug-03-2005
# 688  Zinc and Compounds  7440-66-6               Aug-03-2005
# 689  Zinc and Compounds  7440-66-6               Aug-03-2005
#
#            IRIS SUMMARY TOX REVIEW/SUPPORTING DOCUMENT  \
# 681  (PDF 64 pp, 341 K)            (PDF 197 pp, 1.2 M)
# 685  (PDF 33 pp, 203 K)            (PDF 113 pp, 498 K)
# 687  (PDF 21 pp, 154 K)             (PDF 83 pp, 520 K)
# 688  (PDF 21 pp, 154 K)             (PDF 83 pp, 520 K)
# 689  (PDF 21 pp, 154 K)             (PDF 83 pp, 520 K)
#
#     LITERATURE SCREENING REVIEW CRITICAL EFFECT SYSTEMS TUMOR SITE PESTICIDE  \
# 681                         Yes                 Hepatic    Hepatic       NaN
# 685                          No                 Nervous       None       NaN
# ...

# %%
clean_chem_df[clean_chem_df['CHEMICAL NAME'] == 'Zinc and Compounds'] # checks out with IRIS Assessment page and Zinc and Compounds assessment page
# Out:
#           CHEMICAL NAME      CASRN LAST SIGNIFICANT REVISION  \
# 686  Zinc and Compounds  7440-66-6               Aug-03-2005
# 687  Zinc and Compounds  7440-66-6               Aug-03-2005
# 688  Zinc and Compounds  7440-66-6               Aug-03-2005
# 689  Zinc and Compounds  7440-66-6               Aug-03-2005
#
#            IRIS SUMMARY TOX REVIEW/SUPPORTING DOCUMENT  \
# 686  (PDF 21 pp, 154 K)             (PDF 83 pp, 520 K)
# 687  (PDF 21 pp, 154 K)             (PDF 83 pp, 520 K)
# 688  (PDF 21 pp, 154 K)             (PDF 83 pp, 520 K)
# 689  (PDF 21 pp, 154 K)             (PDF 83 pp, 520 K)
#
#     LITERATURE SCREENING REVIEW CRITICAL EFFECT SYSTEMS TUMOR SITE PESTICIDE  \
# 686                          No     Hematologic; Immune       None       NaN
# 687                          No     Hematologic; Immune       None       NaN
# 688                          No     Hematologic; Immune       None       NaN
# ...

# %%
clean_chem_df.to_csv('EPA_IRIS_Assessments_2021_clean.csv', index=False) # store as csv file
